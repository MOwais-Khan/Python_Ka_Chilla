# %% [markdown]
# # BASIC OF STATISTICS FOR DATA SCIENECE
#
# **Outline** For Statisi week, no about this video only
#
# * Descriptive Statistics
# * Data Visualization
# * Probability Distribution
# * Hypothesis testing
# * Regression Analysis
#
# Important before jumping into statistics
#
#
#
# ## Python Packages or libraries FOR DATA SCIENECE
#
#
# For **Scietific computing**, we will use
#
# * Pandas
# * Numpy
# * SciPy
#
#
# For **Data Visualization**
#
# * Matplotlib
# * Seaborn
#
# For **ML Algorithm Deveopment**
#
# * Scikit-learn
# * Statsmodels
#
# ### STATISTICS:
# Statistics is a collection of methods for collecting, displaying, analyzing and drawing conlusion from data
#
#
# * Data lia--- Collecion me agaya wo
# * phir usko display kia
# * analyse kia
# * Manipulate kia
# * drawing conclusion from it
# * And Preseting it
#
# **Data Analysis** jo he wo STATISTICS he
# **Data Manipulation** is also part of statistics but we will see now hamne krna kia he
#
# **PANDAS** ki library buhat imp he uske sath statisics ki buhat c cheze huti he
#
#
# Jaha b **data** huga waha **statistics** ajaege
#
# STATISTICS IS EVERYWHERE:
#
# * Rain k chances kitne he (Weathe rforecast)
# * USD rate i prediction --- yeh b statisctis ki example he
# * AVg slaary of data analyst or data scientist?
# * ANy comaprision inresearch ------- is also statistics
# * Yaar Thesis ki stat laga do
# * ANOVA etc (Anova test)
#
#
# **Data scientist** is someone who can predict the future based on past patterns
# **Data analyst** is someone who merely curates meaningful insights from data
#
#
#
# ### LANGUAGE OF STATISTICS
#
# jab aapne graphs present krne he so you have to talk in the language of statistics
# ager baat nhn krege to aapka data recognizable nhn huga apka analysis recognizable nhn huga
# you have to work on diff parts of statistics
#
#
# - Average income in Pakistan   (Isme statisics kia he?? AVERAGE--- Mean )------------ Average
# - Highest Score in Cricket match( Highest---- Maximum)--------------------------------Maximum
# - Fastest Bowler         (Speed)------------------------------------------------------Maximum
# - Sabse kam run khaeye   (Minimun) ---------------------------------------------------Minimun
# - 40% teachers in Pakistan are female ( Percent)--------------------------------------Percentage
# - Kal barish kitni huge b k nhn     (Booean)------------------------------------------Likelihood
# - Dollar kabhi uper jata he kabhi neche   (Pendulam)----------------------------------Variance
# - Hotels me larkay ziada kharcha krte he larkion ki nisbat  ( Percent)-----------------(t-test)
# - faisalabad > Lahore > Karachi > Sargodha > Islamabad jugton (Jokes) ki ranking-------(ANOVA)
#
#
# **Language of Statistics kia huti he???**
# Jese, Covid Cases in pakistan
# Publication results  (7 days k hisab se huti he etc)
#
#
#
# ## Data Types-1
#
# #### CROSS SECTIONAL
#
# Data coected at 1 point
# yani aj ye video kitne log dekhre he
# yani aajke din 13 jan k kitne log video dekhre he
#
# **har kisi ka dosre ka sath comparision krege to wo cross sectional huga**
#
#
#
# #### TIME SERIES
#
# **Data coected over diff time points**
#
# ager ushe data ko kahu 1jan se 13jan tak rozana kitne log session me atay rahay he
# that is basically Data coected over time pointsyani 1st ko kitne thay , agle din kitne etc istrha data move krega, jese covid 19 ki example di aapne
#
#
#
#
#
# ## Data Types-2
#
#
# #### UNIVERIATE
#
# **Data contains a single variable t measure entity**
#
# e.g Plant height
# Fertilizer
#
# **Rozana aap kitna khana khatay he us se kitna weight brh raha he aapka**
#
#
# #### MULTI-VARIATE
#
# **Data contains > 2 variables to measure something**
#
# e.g
# 1. Plant height
# 2. Fertilizer amount
# 3. Irrigation time
#
# khana khanay k sath sath pani b pete he to aapka weight itna brh raha
#
# Biryani k stah Coke
# Biryani k sath kuch aur
#
#
#
#
#
# ## Variable Types-1
#
# ### Categorical(Nominal)
#
#
# #### Binomial:
#
# 2 he options he jab
#
# jese True False , NO quantitative Relatioship is given
#
#
#
#
# #### Multinomial:
#
# **Ziada options hu aapke pas**
#
# subha university jatay he ziada options heBUS me , CAR me, Cycle, POINT etc diff choices he unme se 1 choose krke likhte he
# Kahsti wale me WHO ka column thaa, ya male he ya female ya child  -- Binomial
#
#
#
#
#
#
#
#
#
# Variable Types-2
# =============
# ### Categorical(Nominal)
#
#
# #### Ordinal Variable
#
#
# data ranking ya ordered ki base per isay ham krte he
#
# Mere paas kitnay cel phones hyn?  ---- kind of Ordinal Variable
# Categories can be compared
# No fixed unit of measurement for statistics
#
# Yaa per compare krskte he mere pa kitne phones he aur aapke pas kitne he
# lekin wo matter nhn krta compare krege kitne he 1,2,3,4,5,6 lekin usko compare nhn krege
# No fixed unit of measurement for statistics
#
# kitne phones he 2,4,5 yeh quantoty hugae
#
# **mere phne ka size kitna he and apke phone ka size kitna he thats ordinal variable**
# isme data ko rank krte he for exampel jiske pas 4 he wo sabse uper ajaega jiske pas 3 he wo us se neche
# etc
#
#
#
# **Assignment task (sent voice note)**
#
# Ordinal Data Levels of Measurement
# Values of ordinal variables have a meaningful order to them.  For example, education level (with possible values of high school, undergraduate degree, and graduate degree) would be an ordinal variable.  There is a definitive order to the categories (i.e., graduate is higher than undergraduate, and undergraduate is higher than high school), but we cannot make any other arithmetic assumptions beyond that.  For instance, we cannot assume that the difference in education level between undergraduate and high school is the same as the difference between graduate and undergraduate.
#
# We can use frequencies, percentages, and certain non-parametric statistics with ordinal data.  However, means, standard deviations, and parametric statistical tests are generally not appropriate to use with ordinal data.
#
#
#
# ## VARIABLE TYPES-3
# **Ratio Data** dekhte he isme, ISme Natural zero huta he
#
# kal ki nisbat aaj ziada maal bika he Economic Data me
#
# like blessed friday etc usme ziada sale hugae isme ham compariion krte he sale ko pichle dino k muqble me . is comparision ko
#  Ratio Data khte he
#
# for example yaha pe kitne males he kitne females he to isko Ratio data me bhi consider krege
# lekin yeh binomial me bhi askta he but depends aapne kistrah isay use krna he
#
# Isme mensuremnt in units me dekhskte he ham percentage and other data b dekhskte he
#
# Mensuremnt in units and ratios are continous Variabe
#
# **isko Catagorical k sath mix na kryega yeh Continous Variabe ka huta he**
#
# Ration Data: Meri height aapse 10% ida he
#
# !
# VARIABLE TYPES-4
#
# Interval variables/Data
#
# Ordered and Charaterized data
#
#
# Is jUne main garmi ziada hy?
# 2020 ki nisbat
#
# Ratios are meaningless (50 degree is not duble hot of 25 degree)
# Difference are meaningful
#
#
#
#
#
# 25:00 minutes  Examples of Interval Data
#
# Psychological concepts like intelligence are often quantified through operationalization in tests or inventories. These tests have equal intervals between scores, but they do not have true zeros because they cannot measure “zero intelligence” or “zero personality
#
# Interval data, also called an integer, is defined as a data type which is measured along a scale, in which each point is placed at equal distance from one another. Interval data always appears in the form of numbers or numerical values where the distance between the two points is standardized and equal.
#
#
#
# !
# !
# !
# !
# MEASUREMENT OF CENTRAL TENDENCY:
#
# mean, median and mode
#
#
#
# POPULATION VS SAMPLES:
# sample lete he to yah to poi population ka lete he jese mardam shumari huti he paksitan me
# ya samples lie hue hu us base per
#
#
#
#
#
# Population research has more power
#
# Samples are used to reduce th cost of dta collection
#
# Covid 19 Data
#
#
# ### NOTIONS AND TERMS in Statistics
#
#
# **N** = Size of Population
# **n** = sie of Sample
# etc
#
#
# Deeg me chawal dekhna thuri se chakahy. yeh sample ki example he
# Ager pori deeg khata phir population huti
#
#
# **Measurement:**
#
# kisi chez ko napna , ginna
# heght ko
# wight ko
# sampl ki popupaltion ko napna ginna etc
#
# Quantitavily dekhte he
#
# Yeh number huta he ya attribute he .... Sampe Data .
#
#
# **Parameter:**
# Parameter 1 number hua he jo summerize krta he number ko
#
#
# **Statistic:**
# is a number computed from Sample Data
#
# Mean, median, Mode
#
# **Descriptive Statistics:**
#
# Sirf dtako dekh k Mean, Median Mode jo hamne batae thay yeh itni population itni
# Pandas pe jo meri last video aye he thats kind of Descriptive Statistics
#
#
# **Exploratory Data Analysis** refers to the critical process of performing initial investigations on data so as to discover patterns,to spot anomalies,to test hypothesis and to check assumptions with the help of summary statistics and graphical representations.
#
#
# Inferential Statistics
# Jo result nikalte he, decision making kre he wo Inferential Statistics he
#
#
# Qualitative Data:
# Non Numeric Data he
#
# Catagorical data ko Qualitative DATA khte he
#
#
# YES  NO
# Male Female
#
# Yani jisme quantity shamil na hu
#
#
# Quantitative Data:
# Jisme number hu, Numerical ho float values waghera
# Mean
# Average
#
#
#
#
# ### MEAN AND ITS POPERTIES
#
#
# "Meaningful" for Intervals and Ratio data
#
# "Outliers" change the means of Data, therefore "Median" is useful
#
#
# "Median":
# Center wala ager aap kis ko sort krte he ascending ya descidng me
#
#
# in terms median wala jo huga bech wala uske left side pe b uha he huga and right side per bho
# balance form huti he
#
# lekin kab  yeh true huta he kabhi yeh false to depend on data kab median use krege kab mean
#
#
# median me wese right side thura ziada huga left thura , depend ager wo ascending me he
#
#
# Median ki exmple....
# Eidi di mehman ne aapk
#
# chote bhai ko 250
# aapko manjle ko 500
# apki behan ko 1000
#
#
# apka chota bhai ascending order me pehla tha to usay kam milay
# ya wo apse chota he age me islie kam mile
#
#
# - har data set ka apna kamal ka unique median huta he
#
#
# - Outliers dont have any effect on median
# ager aik bachay ki age 2 sal he aur baqi ki 20,30,40,50 he to is 2 saal wae ka koi effect nhn huga median pe
# q k ham middile wale banday ki vaue dekhre he average nhn dekhre
#
#
# - Ratios, Intervals and Ordinal data has best use
#
#
# Kaha kaha median use huga isko yaad rkhne ki zarorat nhn he but idea huna chahye phir bhi
#
#
#
#
#
# ### MODE:
# The value that occurs most frequently
#
# Faisalabad me yadgar ki mithae saddar bazar me buhat FIT he :P
#
#
#
# Measure of Dispursion
# Variability, scatter or spread
#
#
# Dispersion:
# How much data spread around mean
#
#
#
# jab light ati he SUN ki
# prism se guzar ker light 7 colours me phel jati thee Dispurse hujati thee
#
#
# MEAN k ird gird jitna data phela hua he thats actually dispersion
#
#
# Aik line lagadi bech me wo hugaya mean and kitna kitna phela hua he
#
# kisi b data ko compare krne k lie mean enogh nhn huta he , apko dekhna prta he k kitna phela hua he
# left pe kitna right pe . thats called
#
# - Dispersion
# - Standard deviation
# - Standard error may also be called
# - Variance b khte he
# - Bell Curve b khte he
#
#
#
# ##### Example
#
#
# DISPERSON
# caused by diff b/w minimum and maximum
#
# 2 chze mili desribe function se pandas k, waha min and max ka rha tha hamne
# min=
# max=
# min aur max k darmian range dispersion of data
#
# range = min to max
#
# Sd
# Se
# Vriance
# Bell curve
#
# example of Iftari time aap bazar me gae 10mint rehte he
# 5dukan walo se rate pochte he
# aik khta he 5 ka somosa akhri 5 rehgae he lejao
#
# 1 banda 10 ka dera hay
# 1 banda 20 ka
# 1 dera he 50
#
#
# in sab ka mean kren to 25 ka he
#
# to dispersion 5 se 50 ka huga aur iska mean center me huga
#
# Dispersion Formula: or Standard deviasion
#
# google krlo formula uyaad huna zxarori nhn he
#
# unit of dispersion count is Std(Standard deviation)
# variance nikalne
#
# zaroray he nhn he panda sab kr raha he aapko formula yad krne ki zarorat nhn he
#
# population ka ho ya sample ka ho unit std he huta he
#
# Practice krne ko kaha tha wo kren aap log...
#
#
# **To save these formulas at your end**
#
# Standard deviation
# Standard error
# Variance
# Bell curve
#
# sd ko error me kese convert krna he iska formula b dekhskte he internet me
#
# 59:49
#
#
# SD AND MEAN
#
# SD AND MEAN ka role kia he???
#
#
# Data from 100 shops in Ramadan
#
# Mean = 30.1   -- Karahi gosht
# Mean = 30.2   -- Biryani
#
#
# SD = 4.76   -- Karahi gosht
# SD = 10.99   -- Biryani
#
#
# ##### SD AND MEAN RELIABILITY
#
# Mean: Only gives us a small picture
# Means: are incomplete without dispersion(SD)
#
# Mean apko batadeta he k 30 rupee ki plate , dekhlo 30 k kareb kareb hugi
#
# Means: are incomplete without dispersion(SD)
# Q k 50% your decision or your data driven policy making
#
#
# 50% depend krta he apke MEAN per
# 50% depend krta he despersion of data per
#
# to yeh dono mila ker decision banta he 50% yeh 50% wo
#
# panadas ki video me data analysis me hamne prha tha Data driven Policy making ko
#
# Mean with a SD is more useful than only mean by itself
# yani Akeli Averge kuch nhn he Standard deviation k bagher
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# FUNDAMENTALS OF VISUALIZATION
# =============================
#
#
# Basic statistics aapkoprha di he
# ((test kunsa huta he kaha lagra he wo ham baad me dekhege
# baqi majority hamne parhli he ))
#
#
# jo graph hamne banane he unki basics kia huti he wo ham pehle krlete he
#
#
# VARIABLE TYPE MATTERS
#
# Type of visualization depends on the variable type
#
# Categorical Variable
#
# Counts(plot type)
# Males vs female
# True vs False
# 0 vs 1
# Yes vs NO
#
# Categorical Variable k alag graphs banate he Count ya Plot type jo hamne bana ker dekhlie he pehle
# matplotlib aur seaborn me
#
#
# **Continous Variable**
#
# Scatter plot
# Statistical proportions (means and their comparison)
#
#
# **Matplot lib
# **seaborn lbrary
# se ham yeh graphs aban skte he Categorical and Continous Variable
#
#
# also some plants can be drown with Pandas library
# to yeh depend krta he
#
#
# ### 2 types of Data
#
#
# ##### Categorical
#
# Qualitative
# No Numerical meaning
# Represented in texts (e.g character, factors in R)
#
# (jisme koi numbers nhn hute he)
#
#
# #### Continous
#
#
# Qualitative
# Numerical
# Mostly represented in number (e.g: Numerical variable in R)
#
#
#
# (jisme number he  umber hute he)
#
#
#
# #### Categorical
#
#
# YES NO
# TRUE FALSE
# BINOMIAL
#
# TRINOMIAL b huiskte he
#
# me example sirf Qualitative ki deta hu  abhi
#
#
# - Yes and NO answer
# (Have you ever been to Lahore?)
# Which gene was expressed?
# Do you like Mangoes? "yes" or "No"
#
#
# ##### Continous
#
#
# ##### Quantitative
#
# Examples:
#
# Amount
# Number
# Age
# Plant height
# Number of bacterial colonies
# Chlorophyll content
# Fertilizer Amount
#
# kisi chez ko napna , ginna,
#
# Quantity
#
# Chart Suggestions - A Thought-Starter from the Extreme Presentation tm METHOD created by Dr Andrew Abela
#
# Kuns Plot kab kiswqt banana he. Explore in google... its very important
#
#
# Nominal
# Binominal
# Multinomial
#
# Yeh sab aapko pata chal gaya he
